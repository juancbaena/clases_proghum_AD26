# %% [markdown]
# # Sesión 3: Sintaxis de Python, variables y tipos de datos
# Dr. Juan Carlos Baena Silva
#
# ---
# ## Contenidos en este cuaderno
# 1. Google Colab
# 2. Mostrar mensajes con `print()` y escribir comentarios.
# 3. Crear **variables** y reconocer **tipos de datos** (texto, números, verdadero/falso).
# 4. Hacer **operaciones** y combinar texto.
# 5. Pedir datos a la persona usuaria con `input()`.
# 6. Ejercicios individuales

# %% [markdown]
# ## Cómo se usa Google Colab
#
# Un cuaderno de Colab está hecho de **celdas**. Hay dos tipos:
#
# - **Celdas de texto** (como esta), con explicaciones.
# - **Celdas de código**, que contienen instrucciones de Python y se pueden **ejecutar**.
#
# Para ejecutar una celda de código, haz clic en ella y presiona **Shift + Enter**
# (o el botón ▶️ a su izquierda).
#
# Prueba ahora con la siguiente celda:

# %%
print("¡Hola! Ya estoy ejecutando mi primer programa.")

# %% [markdown]
# Si viste el mensaje debajo de la celda, ¡todo funciona! Acabas de **ejecutar código**.
#
# > 💡 No tengas miedo de equivocarte. En programación, **el error es parte del proceso**:
# > se prueba, se lee el mensaje, se corrige y se vuelve a intentar.

# %% [markdown]
# ## 1. Mostrar mensajes: `print()` y comentarios
#
# `print()` muestra en pantalla lo que pongas entre paréntesis.
# Una línea que empieza con `#` es un **comentario**: Python la ignora, sirve para anotar.

# %%
# Esto es un comentario: no se ejecuta.
print("Hola, humanidades digitales")
print("Hoy aprendo a programar")

# %% [markdown]
# ## 2. Variables: guardar información con un nombre
#
# Una **variable** es una etiqueta que guarda un valor para reutilizarlo. Se asigna con `=`.

# %%
autor = "Miguel de Cervantes"
titulo = "Don Quijote de la Mancha"
anio = 1605

print(autor)
print(titulo)
print(anio)

# %% [markdown]
# ## 3. Tipos de datos
#
# Cada valor tiene un **tipo**. Los más básicos:
#
# - `str` → texto (cadena), va entre comillas: `"Cervantes"`
# - `int` → número entero: `1605`
# - `float` → número con decimales: `3.14`
# - `bool` → valor lógico: `True` (verdadero) o `False` (falso)
#
# La función `type()` nos dice el tipo de un valor.

# %%
print(type(autor))   # texto -> str
print(type(anio))    # entero -> int
print(type(3.14))    # decimal -> float
print(type(True))    # logico -> bool

# %% [markdown]
# ## 4. Operaciones con números
#
# Python funciona como una calculadora: `+`, `-`, `*`, `/`, y `**` (potencia).

# %%
anio_actual = 2026
antiguedad = anio_actual - anio
print("Antiguedad de la obra (años):")
print(antiguedad)

# %% [markdown]
# ### Ejemplo

# %%
resultado_ejercicio1 = 2 + 4
resultado_ejercicio2 = 18 - 9
resultado_ejercicio3 = 3 * 4
resultado_ejercicio4 = 30 / 3
resultado_ejercicio5 = 5 ** 2
print(resultado_ejercicio1)
print(resultado_ejercicio2)
print(resultado_ejercicio3)
print(resultado_ejercicio4)
print(resultado_ejercicio5)

# %% [markdown]
# ## 5. Trabajar con texto: unir cadenas y *f-strings*
#
# Podemos **unir** texto con `+`, pero la forma más cómoda es la **f-string**:
# se escribe una `f` antes de las comillas y se ponen las variables entre llaves `{ }`.

# %%
# Union simple con +
print(autor + " escribió " + titulo)

# Forma recomendada: f-string
referencia = f"{autor} escribió en  ({anio}) la obra {titulo}."
print(referencia)

# %% [markdown]
# ## 6. Pedir datos: `input()`
#
# `input()` detiene el programa y espera a que la persona escriba algo.
# **Importante:** lo que devuelve `input()` siempre es **texto (`str`)**. Si necesitamos un número,
# lo convertimos con `int()` o `float()`.

# %%
titulo_usuario = input("Titulo del libro: ")
autor_usuario = input("Autor: ")
anio_texto = input("Anio de publicacion: ")

anio_numero = int(anio_texto)   # convertimos el texto a numero entero

ficha = f"{autor_usuario} ({anio_numero}). {titulo_usuario}."
print("\nReferencia generada:")
print(ficha)

# %% [markdown]
# > 💡 **Error muy común (y muy útil para enseñar):** si intentas restar o sumar con el
# > resultado de `input()` sin convertirlo, Python se queja porque está mezclando texto y números.
# > Ese error es una gran oportunidad para explicar la diferencia entre `str` e `int`.

# %% [markdown]
# ## 7. Ejercicios graduados
#
# Resuelve en orden. Cada nivel sube un escalón. **No es obligatorio llegar al reto**: la idea es
# que cada quien avance hasta donde se sienta con confianza.
#
# **Nivel 1 (base).** Crea tres variables: `nombre_estudiante`, `materia` y `universidad`.
# Imprime una frase con una f-string, por ejemplo:
# `"Ana cursa Humanidades Digitales en el Tec."`
#
# **Nivel 2.** Pide con `input()` el nombre de una persona autora y dos años (nacimiento y muerte).
# Calcula y muestra cuántos años vivió.
#
# **Reto (opcional).** Pide un texto corto y muestra cuántos **caracteres** tiene
# (pista: la función `len()` cuenta la longitud de una cadena).

# %% [markdown]
# ### Nivel 1

# %%
# Escribe aqui tu solucion del Nivel 1:

# %% [markdown]
# <details>
# <summary>👀 Ver una solución posible del Nivel 1</summary>
#
# ```python
# nombre_estudiante = "Ana"
# materia = "Humanidades Digitales"
# universidad = "Tec"
# print(f"{nombre_estudiante} cursa {materia} en el {universidad}.")
# ```
# </details>

# %% [markdown]
# ### Nivel 2

# %%
# Escribe aqui tu solucion del Nivel 2:

# %% [markdown]
# <details>
# <summary>👀 Ver una solución posible del Nivel 2</summary>
#
# ```python
# autor = input("Nombre de la persona autora: ")
# nacimiento = int(input("Anio de nacimiento: "))
# muerte = int(input("Anio de muerte: "))
# print(f"{autor} vivio {muerte - nacimiento} anios.")
# ```
# </details>

# %% [markdown]
# ### Reto

# %%
# Escribe aquí tu solución al reto

# %% [markdown]
# ### Material extra:
#
# [Introducción a Google Colab para principiantes | Mini curso](https://www.youtube.com/watch?v=OtWpvohdxLY&list=PLMUejNMebG_VGByQwI2dUF5qdwxi8QqBx)

# %% [markdown]
# # Ejercicios extra
# Resuelve estos tres retos cortos. Son del mismo nivel del Cuaderno 1; la meta es **ganar soltura**.
#
# 1. Crea una variable `ciudad` con el nombre de tu ciudad e imprímela dentro de una frase.
# 2. Crea dos variables numéricas y muestra su suma con una f-string.
# 3. Pide el nombre de un libro con `input()` y salúdalo: `"Hoy trabajaremos con <libro>"`.

# %%
# Reto 1: tu ciudad

# %%
# Reto 2: suma de dos numeros

# %%
# Reto 3: input con el nombre de un libro

# %% [markdown]
# # Mini-Taller graduado
# # Tema: f-strings y el uso de "input"
# El día de hoy vamos a repasar cómo se usan las "f-strings" con variables creadas directamente en el código y con variables que usan el comando "input" que habilita texto insertado por el usuario
#
# *Recordemos*
#
# La sintaxis de las "f-strings" es:
#
# `f"texto {variable}"`
#
# La sintaxis del comando input es:
#
# `variable = input("texto que aparece en la solicitud")`

# %% [markdown]
# ## Ejercicios de texto y variables
# 1. Ejercicio 1: Crea una variable llamada colonia y escribe el nombre de tu colonia e imprime usando f-string "Hola, yo vivo en la colonia: {colonia}"
# 2. Ejercicio 2: Crea dos variables una llamada: "nombre" con tu nombre, la segunda "ciudad", imprime usando f-strings: "Hola, mi nombre es: {variable 1} y vivo en {variable 2}
# 3. Crea tres variables con un tema libre y una f-string que emplee las 3 variables

# %%
# Ejercicio 1

# %%
#Ejercicio 2

# %%
#Ejercicio 3

# %% [markdown]
# ## Ejercicios con el comando input()
# 1. Crea una variable que emplee el comando input llamada bebida, el texto del input debe ser: "Cuál es tu bebida favorita", imprime la variable con una f-string así: "Mi bebida favorita es <bebida>"
# 2. Crea dos variables que soliciten el comando input, la primera es nombre y solicita el nombre del usuario, la segunda ciudad y solicita la ciudad del usuario, imprime las variables de la siguiente manera: "Hola, mi nombre es: <nombre_usuario>" y vivo en: <ciudad_usuario>"
# 3. Crea tres variables que soliciten información diversa del usuario e imprime las tres con una f-string

# %%
# Ejercicio 1

# %%
# Ejercicio 2

# %%
# Ejercicio 3
